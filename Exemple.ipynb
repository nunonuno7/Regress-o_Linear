# %%
## Importar o Modelo de Regressão Linear

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Defenir a variável dependete y (output) e a variavel independente x (input)
data =pd.read_csv("Salary_Data.csv")
X = data.iloc[:, 0]
Y = data.iloc[:, 1]
plt.scatter(X, Y)
plt.show()

# %%
# Importar a nossa classe e correr o modelo

from LinearRegressionGD import LinearRegressionGD
model = LinearRegressionGD(learning_Rate=0.0001,max_iter=1000,min_delta_iter=0.0002)
model.fit(X,Y)
# Out:
# (12718.116024804602, 2471.4441260907156)

# %%
## Razão da Paragem min_delta_iter ou max_iter?
model.reason
# Out:
# 'Parou com um delta_iter de -0.0001 '

# %%
# plot com as observações e o y_pred

plt.scatter(X, Y) 
plt.plot([min(X), max(X)], [min(model.Y_pred), max(model.Y_pred)], color='red')  # regression line
plt.show()

# %%
# Precisão de Outputs

x_ = [4.5,8,9]
preditct = [model.predict(_) for _ in x_]
# Out:
# Para um X de 4.5 o Output esperado é 66854.76
# Para um X de 8 o Output esperado é 102215.72
# Para um X de 9 o Output esperado é 112318.85

# %%
# Precisão de Outputs com um dado promt.input

model.predict_input()
# Out:
# Deve ser selecionado um número, ou saia da função, por favor, tente mais uma vez!
# Para um X de 5.0 o Output esperado é 71906.32
